# %% [markdown]
# # Exploratory Data Analysis
#
# Notebook containing exploratory data analysis of various financial returns.
#
# Data Notes:
#
# - GDAX exchange had a system error in 2017-04-16 that led to BTC value crashing to 0.06, this is erroneous and was dropped from the data (only discovered this through manual inspection and subsequent googling)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kurtosis

# %%
# data read in and adjustment
sp500_raw_data = pd.read_csv("./data/all_stocks_5yr.csv")
sp500_index_data = pd.read_csv("./data/sp500index.csv")
btc_data = pd.read_csv("./data/GDAX-USD.csv")

sp500_raw_data.index = sp500_raw_data["date"].astype('datetime64[ns]') # set index to dates
sp500_raw_data.drop(columns=['date'],inplace=True) # drop extra Date column

sp500_index_data.index = sp500_index_data["Date"].astype('datetime64[ns]')
sp500_index_data.drop(columns=['Date'],inplace=True)

btc_data.index = btc_data["Date"].astype('datetime64[ns]')
btc_data.drop(columns=['Date'],inplace=True)

# %% [markdown]
# Upon manual inspection of GDAX BTC/USD found that there was a system price glitch on '2017-04-16' that erroneously showed the price as 0.06 --> solution: removed this data point from time series.

# %%
btc_data.drop()

# %%
sp500_index_data.head()
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 1950-01-03  16.66  16.66  16.66  16.66      16.66  1260000
# 1950-01-04  16.85  16.85  16.85  16.85      16.85  1890000
# 1950-01-05  16.93  16.93  16.93  16.93      16.93  2550000
# 1950-01-06  16.98  16.98  16.98  16.98      16.98  2010000
# 1950-01-09  17.08  17.08  17.08  17.08      17.08  2520000

# %%
sp500_raw_data.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
btc_data.head()
# Out:
#                Open     High      Low        Volume
# Date
# 2018-05-10  9310.01  9386.32  9054.99   7178.456484
# 2018-05-09  9193.00  9370.00  8960.00   8709.548871
# 2018-05-08  9310.01  9463.13  9050.00   9578.256001
# 2018-05-07  1727.01  1765.10  1558.00  32982.939177
# 2018-05-06  9788.01  9880.00  9390.00   7704.905922

# %% [markdown]
# ## Returns
#
# Plotting the time series plot of the prices. Converting prices into returns and plotting their histogram.

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(sp500_index_data.index, sp500_index_data['Close'])
plt.grid(True)
plt.ylabel('Price')
plt.legend(['S&P500']);

# %%
sp500_returns = sp500_index_data['Close'].pct_change()[1:]
sp500_returns.plot(title='S&P500 Returns',grid=True, figsize=(8, 6));

# %% [markdown]
# Upon manual inspection of GDAX BTC/USD found that there was a system price glitch on '2017-04-16' that erroneously showed the price as 0.06 --> solution: removed this data point from time series

# %%
plt.figure(figsize=(12, 9), dpi=150)
plt.plot(btc_data.index, btc_data['Open'])
plt.grid(True)
plt.ylabel('Price')
plt.legend(['BTC/USD']);

# %%
btc_returns = btc_data['Open'].pct_change()[1:]
btc_returns.plot(title='BTC/USD Returns', grid=True, figsize=(12,9));

# %% [markdown]
# Clearly due to BTC's extreme volatility there is a huge jump in returns around last year, let us consider snippets of time prior, during and after this period.

# %%
btc_returns[btc_returns == max(btc_returns)]
# Out:
# Date
# 2017-04-14    19593.5
# Name: Open, dtype: float64

# %%
btc_returns['2017-04']
# Out:
# Date
# 2017-04-30       -0.010936
# 2017-04-29       -0.018896
# 2017-04-28        0.009198
# 2017-04-27       -0.038545
# 2017-04-26       -0.015263
# 2017-04-25       -0.017497
# 2017-04-24       -0.007940
# 2017-04-23        0.000368
# 2017-04-22       -0.003744
# 2017-04-21       -0.008464
# 2017-04-20       -0.023017
# 2017-04-19       -0.004062
# 2017-04-18       -0.007999
# 2017-04-17       -0.009934
# 2017-04-16       -0.999949
# 2017-04-14    19593.500000
# 2017-04-13        0.031072
# 2017-04-12        0.012011
# 2017-04-11       -0.014917
# 2017-04-10        0.002896
# 2017-04-09       -0.024638
# 2017-04-08        0.007546
# 2017-04-07        0.006280
# 2017-04-06       -0.059124
# 2017-04-05        0.012078
# 2017-04-04        0.011216
# 2017-04-03       -0.035813
# 2017-04-02       -0.024453
# 2017-04-01        0.005048
# Name: Open, dtype: float64

# %%
btc_data['2017-04']
# Out:
#                Open     High      Low        Volume
# Date
# 2017-04-30  1367.50  1394.51  1334.02  10301.225627
# 2017-04-29  1341.66  1369.50  1335.64  10215.123156
# 2017-04-28  1354.00  1381.01  1300.20  13547.821826
# 2017-04-27  1301.81  1360.00  1295.00  10326.646524
# 2017-04-26  1281.94  1320.00  1279.10   9635.842423
# 2017-04-25  1259.51  1287.00  1256.16   7998.287701
# 2017-04-24  1249.51  1261.16  1246.31   5903.952659
# 2017-04-23  1249.97  1254.00  1236.20   4982.370478
# 2017-04-22  1245.29  1253.00  1221.51   6303.592957
# 2017-04-21  1234.75  1258.77  1232.06   6575.354347
# 2017-04-20  1206.33  1240.60  1205.51   8066.892474
# 2017-04-19  1201.43  1207.44  1191.09   5937.762110
# 2017-04-18  1191.82  1206.65  1188.74   6307.299927
# 2017-04-17  1179.98  1197.60  1170.85   6439.799729
# 2017-04-16     0.06  1189.93     0.06   3402.960674
# 2017-04-14  1175.67  1196.92  1169.55   5673.728979
# 2017-04-13  1212.20  1219.49  1148.98   9436.010499
# 2017-04-12  1226.76  1228.32  1209.61   6442.439292
# 2017-04-11  1208.46  1234.00  1200.00   5434.490239
# 2017-04-10  1211.96  1219.78  1201.00   5599.218172
# 2017-04-09  1182.10  1221.00  1175.80   5827.944967
# 2017-04-08  1191.02  1198.00  1170.00   4575.835381
# 2017-04-07  1198.50  1203.00  1175.26   7015.058720
# 2017-04-06  1127.64  1206.97  1127.56  11240.027163
# 2017-04-05  1141.26  1144.99  1114.90   8603.573272
# 2017-04-04  1154.06  1164.14  1124.98   9314.083896
# 2017-04-03  1112.73  1168.72  1108.94  12497.687114
# 2017-04-02  1085.52  1119.00  1080.00   7642.383520
# 2017-04-01  1091.00  1110.95  1071.45   6968.289809

# %% [markdown]
# ## Kurtosis
