# %% [markdown]
# Based on brief empirical results from Dimitris's model-free textbook I aim to explore whether other financial time series also suggest infinite fourth moment.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kurtosis

raw_data = pd.read_csv("./Data/all_stocks_5yr.csv")

# %%
aapl_price = raw_data[raw_data['Name'] == "AAPL"]

# %%
aapl_price['close'].plot()

# %%
aapl_returns = aapl_price['close'].pct_change()[1:]

# %%
aapl_returns.plot()

# %%
plt.hist(aapl_returns, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['AAPL Returns']);

# %%
aapl_returns.index = range(0,len(aapl_returns)) # reformat index

# %%
aapl_kurtosis = np.zeros(len(aapl_returns),dtype=float)
# Out:
# 0       0.010422
# 1      -0.025067
# 2      -0.001903
# 3      -0.000899
# 4      -0.013780
# 5      -0.000370
# 6      -0.024218
# 7      -0.006216
# 8       0.010649
# 9      -0.017768
# 10      0.013934
# 11     -0.009801
# 12     -0.007130
# 13     -0.024762
# 14     -0.024207
# 15      0.026410
# 16     -0.012714
# 17      0.011559
# 18      0.002642
# 19      0.014246
# 20     -0.021559
# 21     -0.000186
# 22      0.009689
# 23      0.025802
# 24      0.027184
# 25     -0.002699
# 26     -0.005303
# 27      0.001437
# 28      0.020278
# 29      0.003614
#           ...
# 1228   -0.025370
# 1229    0.000176
# 1230    0.002814
# 1231   -0.010814
# 1232    0.017905
# 1233   -0.000174
# 1234    0.004645
# 1235    0.011385
# 1236   -0.003714
# 1237   -0.000115
# 1238   -0.000229
# 1239    0.005680
# 1240    0.010326
# 1241   -0.005082
# 1242    0.016516
# 1243    0.000893
# 1244   -0.004463
# 1245   -0.008181
# 1246    0.000226
# 1247   -0.015929
# 1248   -0.017851
# ...
